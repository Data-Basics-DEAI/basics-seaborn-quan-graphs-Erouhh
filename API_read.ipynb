# %%
import requests, json

# %%
# Response will be saved here
nasa_data="nasa_data.json"

# Request to `NASA` API
api_key = "auw4yB06HDB3YLO1pWTBOpOD24Shun6Ee8fURudt"
url = f"https://api.nasa.gov/neo/rest/v1/feed?start_date=2023-09-13&end_date=2023-09-20&api_key={api_key}"

response = requests.get(url)

if response.status_code == 200:
    json_data = response.json()
    print(f"Total asteroids close to passing Earth: {json_data['element_count']}")
else:
    print(f"Request failed with status code {response.status_code}")

with open(nasa_data,"w") as file:
       json.dump(json_data,file,indent=4)
# Out:
# [{'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3314051?api_key=auw4yB06HDB3YLO1pWTBOpOD24Shun6Ee8fURudt'}, 'id': '3314051', 'neo_reference_id': '3314051', 'name': '(2006 BN55)', 'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3314051', 'absolute_magnitude_h': 20.06, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2585562121, 'estimated_diameter_max': 0.5781492662}, 'meters': {'estimated_diameter_min': 258.5562120799, 'estimated_diameter_max': 578.1492662155}, 'miles': {'estimated_diameter_min': 0.1606593321, 'estimated_diameter_max': 0.3592451877}, 'feet': {'estimated_diameter_min': 848.2815628403, 'estimated_diameter_max': 1896.8152385706}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2023-09-13', 'close_approach_date_full': '2023-Sep-13 00:38', 'epoch_date_close_approach': 1694565480000, 'relative_velocity': {'kilometers_per_second': '11.7879055139', 'kilometers_per_hour': '42436.45984995', 'miles_p
# ...
